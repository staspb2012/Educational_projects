# %%
import pandas as pd

# %%
cinema = pd.read_csv('https://gist.githubusercontent.com/tiangechen/b68782efa49a16edaf07dc2cdaa855ea/raw/0c794a9717f18b094eabab2cd6a6b9a226903577/movies.csv')
cinema
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %% [markdown]
# <b>Dataframe 'Cinema'</b> содержит 77 строк и 8 колонок: 'Film', 'Genre', 'Lead Studio', 'Audience score %', 'Profitability','Rotten Tomatoes %', 'Worldwide Gross', Dataframe 'Cinema'не имеет пустых значений, имеет дубликаты
# <h3>Колонки</h3>
# <ol> <li><b>Film</b> - колонка с данными типу object, вмещает в себе названия фильмов.</li>
#   <ul><li>количество фильмов  - 75 (были удалены дублякаты для: "Mamma Mia!",	"Gnomeo and Juliet" ).</li>  </ul>
# <li><b>Genre</b> - колонка с данными типу object , отображвет жанры кинокартин:</li>
#     <ul>
# <li>представленно 6 жанров: 'Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Action'(после корректирования)</li>
# <li> больше всего фильмов жанра 'Comedy'- 42, наименьше у жанров 'Fantasy' - 1 и 'Action' - 1, соответственно жанры 'Romance' - 15, 'Drama' - 13, 'Animation' - 3. </li>
# <li> максимальное значение положительных отзывов "Audience score %" имеют жанры "Drama" - 89% и  "Animation" - 89%, минимальное значение пренадлежит жанру "Comedy" - 35%, наибольшее среднее значение пренадлежит "Animation" - 21% (среднее значение для жанров "Fantasy", "Action" не подсчитаны так, как имеют по одному фильму)</li>
#     <li> максимальное значение положительных отзывов "Audience score %" имеют жанры "Drama" - 89% и  "Animation" - 89%, минимальное значение пренадлежит жанру "Comedy" - 35%, наибольшее среднее значение пренадлежит "Animation" - 21% (среднее значение для жанров "Fantasy", "Action" не подсчитаны так, как имеют по одному фильму)</li>
#     <li> максимальное значение 'Profitability'  имеют жанр "Drama" - 66.9 , минимальные значение пренадлежат жанрам "Comedy" - 0 и "Romance"  - 0, наибольшее среднее значение пренадлежит "Drama" - 17.9 (среднее значение для жанров "Fantasy", "Action" не подсчитаны так, как имеют по одному фильму)</li>
#    <li> максимальное значение 'Rotten Tomatoes %'  имеют жанр "Animation" - 96% , минимальные значение пренадлежат жанру "Comedy" - 3%, наибольшее среднее значение пренадлежит "Romance" - 28.58% (среднее значение для жанров "Fantasy", "Action" не подсчитаны так, как имеют по одному фильму) </li>
#   <li> максимальное значение 'Worldwide Gross'  имеют жанр "Romance" - $702,17 млн, минимальные значение пренадлежат жанру "Romance" - 0,03 млн, наибольшее среднее значение пренадлежит жанру "Drama" - 187,63 млн (среднее значение для жанров "Fantasy", "Action" не подсчитаны так, как имеют по одному фильму) </li>
#     </ul>
# <li><b>Lead Studio</b> - колонка с данными типу object, информирует о компании, которая сняла фильм.</li>
# <li><b>Audience score %</b> - колонка типу int64, выражается в процентрах,так как представляет собой процент пользователей, положительно оценивших фильм.</li>
# <li><b>Profitability</b> - колонка с данными типу float64,вмещает данные о прибыльности картины, расчитывается по формуле прибыльность = сборы / бюджет.</li>
# <li><b>Rotten Tomatoes %</b> - колонка с данными типу int64, выражается в процентрах, данные пердосталяет сайт-агрегатор рецензий, который подсчитывает процент положительных отзывов и средний балл в рецензиях, опубликованных другими изданиями.</li>
# <li><b>Worldwide Gross</b> - колонка с данными типу object, вмещает данные о мировом брутто, что выражается в сумме внутреного дохода и международного дохода от картины.</li>
# <li><b>Year</b> - колонка с данными типу int64, показывает год выхода картины.</li>
# </ol>

# %%
#Выводим общую информацию по датафрейму
cinema.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               77 non-null     object
#  1   Genre              77 non-null     object
#  2   Lead Studio        77 non-null     object
#  3   Audience score %   77 non-null     int64
#  4   Profitability      77 non-null     float64
#  5   Rotten Tomatoes %  77 non-null     int64
#  6   Worldwide Gross    77 non-null     object
#  7   Year               77 non-null     int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
#Выводим количество столбцов и колонок
cinema.shape
# Out:
# (77, 8)

# %%
#Выводим все колонки датафрейма
cinema.columns
# Out:
# Index(['Film', 'Genre', 'Lead Studio', 'Audience score %', 'Profitability',
#        'Rotten Tomatoes %', 'Worldwide Gross', 'Year'],
#       dtype='object')

# %%
#Проверяем наличие пропущеных значений 
cinema.isna().sum()
# Out:
# Film                 0
# Genre                0
# Lead Studio          0
# Audience score %     0
# Profitability        0
# Rotten Tomatoes %    0
# Worldwide Gross      0
# Year                 0
# dtype: int64

# %%
#Выводим верхние значения для ознакомления с датафреймом
cinema.head(15)
# Out:
#                                    Film      Genre            Lead Studio  \
# 0            Zack and Miri Make a Porno    Romance  The Weinstein Company
# 1                       Youth in Revolt     Comedy  The Weinstein Company
# 2    You Will Meet a Tall Dark Stranger     Comedy            Independent
# 3                          When in Rome     Comedy                 Disney
# 4                 What Happens in Vegas     Comedy                    Fox
# 5                   Water For Elephants      Drama       20th Century Fox
# 6                                WALL-E  Animation                 Disney
# 7                              Waitress    Romance            Independent
# 8                   Waiting For Forever    Romance            Independent
# 9                       Valentine's Day     Comedy           Warner Bros.
# 10  Tyler Perry's Why Did I get Married    Romance            Independent
# 11              Twilight: Breaking Dawn    Romance            Independent
# ...

# %%
#Выводим нижние значения для ознакомления с датафреймом
cinema.tail(15)
# Out:
#                           Film      Genre   Lead Studio  Audience score %  \
# 62             Good Luck Chuck     Comedy     Lionsgate                61
# 63          Going the Distance     Comedy  Warner Bros.                56
# 64           Gnomeo and Juliet  Animation        Disney                52
# 65           Gnomeo and Juliet  Animation        Disney                52
# 66  Ghosts of Girlfriends Past     Comedy  Warner Bros.                47
# 67            Four Christmases     Comedy  Warner Bros.                52
# 68                   Fireproof      Drama   Independent                51
# 69                   Enchanted     Comedy        Disney                80
# 70                   Dear John      Drama          Sony                66
# 71                   Beginners     Comedy   Independent                80
# 72         Across the Universe    romance   Independent                84
# 73               A Serious Man      Drama     Universal                64
# ...

# %%
#Проверяем данные на дублирование для значений по которым собирали данные
cinema['Film'].value_counts()
# Out:
# Mamma Mia!                    2
# Gnomeo and Juliet             2
# Zack and Miri Make a Porno    1
# Love & Other Drugs            1
# Killers                       1
#                              ..
# She's Out of My League        1
# Something Borrowed            1
# Tangled                       1
# The Back-up Plan              1
# (500) Days of Summer          1
# Name: Film, Length: 75, dtype: int64

# %%
#Проверяем данные в дубликате 
cinema[cinema['Film'] == 'Gnomeo and Juliet']
# Out:
#                  Film      Genre Lead Studio  Audience score %  Profitability  \
# 64  Gnomeo and Juliet  Animation      Disney                52       5.387972
# 65  Gnomeo and Juliet  Animation      Disney                52       5.387972
#
#     Rotten Tomatoes % Worldwide Gross  Year
# 64                 56        $193.97   2011
# 65                 56        $193.97   2011

# %%
#Проверяем данные в дубликате 
cinema[cinema['Film'] == 'Mamma Mia!']
# Out:
#           Film   Genre Lead Studio  Audience score %  Profitability  \
# 45  Mamma Mia!  Comedy   Universal                76       9.234454
# 46  Mamma Mia!  Comedy   Universal                76       9.234454
#
#     Rotten Tomatoes % Worldwide Gross  Year
# 45                 53        $609.47   2008
# 46                 53        $609.47   2008

# %% [markdown]
# # После подсчета количества фильмов,было определено, что два фильма имеют дубликаты с аналогичными значениями.Данные дубликаты быдут выдалены для избежания влиянния на подсчет статистики.

# %%
#Удаляем дубликаты 
del_dup_cinema = cinema.drop_duplicates(keep='last')
del_dup_cinema
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
#Проверяем операцию по удалению дубликатов
del_dup_cinema['Film'].value_counts()
# Out:
# Zack and Miri Make a Porno    1
# Jane Eyre                     1
# Killers                       1
# Knocked Up                    1
# Leap Year                     1
#                              ..
# She's Out of My League        1
# Something Borrowed            1
# Tangled                       1
# The Back-up Plan              1
# (500) Days of Summer          1
# Name: Film, Length: 75, dtype: int64

# %%
#Выводим уникальные значение по колонке 'Genre'
cinema['Genre'].unique()
# Out:
# array(['Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Romence',
#        'Comdy', 'Action', 'romance', 'comedy'], dtype=object)

# %%
#Выводим количестово каждого значение в колонке 'Genre'
del_dup_cinema['Genre'].value_counts()
# Out:
# Comedy       42
# Romance      15
# Drama        13
# Animation     3
# Fantasy       1
# Action        1
# Name: Genre, dtype: int64

# %% [markdown]
# # В ходе просмотра данных по колонке "Genre" было установаленно, что названия  имеют дублика в нижнем регистре, что повлияет на дальнейшую работу с данными.

# %%
#Редактируем некоректные значения для по колонки 'Genre'
del_dup_cinema['Genre'] = del_dup_cinema['Genre'].replace(['romance','Romence'],'Romance')
# Out:
# C:\Users\Стас\AppData\Local\Temp\ipykernel_13644\1986522340.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del_dup_cinema['Genre'] = del_dup_cinema['Genre'].replace(['romance','Romence'],'Romance')

# %%
#Проверяем значение 'Comdy' для по колонки 'Genre'
del_dup_cinema[del_dup_cinema['Genre'] == 'Comdy']
# Out:
#              Film  Genre Lead Studio  Audience score %  Profitability  \
# 47  Made of Honor  Comdy        Sony                61       2.649068
#
#     Rotten Tomatoes % Worldwide Gross  Year
# 47                 13        $105.96   2008

# %% [markdown]
# # Для уточнения информации по  'Comdy' для 'Genre'  произведен поиск по названию фильма.

# %%
#Редактируем некоректные значения для по колонки 'Genre'
del_dup_cinema['Genre'] = del_dup_cinema['Genre'].replace(['comedy','Comdy'],'Comedy')
# Out:
# C:\Users\Стас\AppData\Local\Temp\ipykernel_13644\3616806973.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del_dup_cinema['Genre'] = del_dup_cinema['Genre'].replace(['comedy','Comdy'],'Comedy')

# %%
#Выводим количестово каждого значение в колонке 'Genre' после корретировки 
del_dup_cinema['Genre'].value_counts()
# Out:
# Comedy       40
# Romance      15
# Drama        13
# Animation     3
# Fantasy       1
# Comdy         1
# Action        1
# comedy        1
# Name: Genre, dtype: int64

# %%
#Проверяем уникальные значение в колонке 'Genre' после корретировки
del_dup_cinema['Genre'].unique()
# Out:
# array(['Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Action'],
#       dtype=object)

# %%
#Удаляем символ "$" для дальнейшей работы с колонкой 'Worldwide Gross'
#и изменяем тип на float для проведение математических операций
del_dup_cinema['Worldwide Gross']= del_dup_cinema['Worldwide Gross'].str.replace('$', '')
del_dup_cinema[['Worldwide Gross']].astype(float)
# Out:
# C:\Users\Стас\AppData\Local\Temp\ipykernel_7512\2879174336.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   del_dup_cinema['Worldwide Gross']= del_dup_cinema['Worldwide Gross'].str.replace('$', '')
#     Worldwide Gross
# 0             41.94
# 1             19.62
# 2             26.66
# 3             43.04
# 4            219.37
# ..              ...
# 72            29.37
# 73            30.68
# 74             8.97
# 75           160.31
# 76            60.72
#
# [75 rows x 1 columns]

# %%
#Спомошью групировки по колонке 'Genre' получаем максимальные значения для каждого жанра и название картины 
del_dup_cinema.groupby('Genre').agg({
  "Audience score %": "max",
  "Profitability": "max",
  "Rotten Tomatoes %": "max",
  "Worldwide Gross": "max"  
}).reset_index()
# Out:
#        Genre  Audience score %  Profitability  Rotten Tomatoes %  \
# 0     Action                45       1.245333                 11
# 1  Animation                89       5.387972                 96
# 2     Comedy                83      22.913136                 93
# 3      Drama                89      66.934000                 89
# 4    Fantasy                81       1.783944                 73
# 5    Romance                84      11.089742                 93
#
#   Worldwide Gross
# 0         $93.40
# 1        $521.28
# 2         $96.16
# 3          $8.97
# 4        $285.43
# 5        $702.17

# %%
#Спомошью групировки по колонке 'Genre' получаем минимальное значения для каждого жанра 
del_dup_cinema.groupby('Genre').agg({
  "Audience score %": "min",
  "Profitability": "min",
  "Rotten Tomatoes %": "min",
  "Worldwide Gross": "min"  
}).reset_index()
# Out:
#        Genre  Audience score %  Profitability  Rotten Tomatoes %  \
# 0     Action                45       1.245333                 11
# 1  Animation                52       1.365692                 56
# 2     Comedy                35       0.000000                  3
# 3      Drama                40       0.448645                 18
# 4    Fantasy                81       1.783944                 73
# 5    Romance                47       0.000000                  6
#
#   Worldwide Gross
# 0         $93.40
# 1        $193.97
# 2        $102.22
# 3         $10.70
# 4        $285.43
# 5          $0.03

# %%
del_dup_cinema[del_dup_cinema['Genre'] == 'Action']
# Out:
#        Film   Genre Lead Studio  Audience score %  Profitability  \
# 55  Killers  Action   Lionsgate                45       1.245333
#
#     Rotten Tomatoes % Worldwide Gross  Year
# 55                 11         $93.40   2010

# %%
#Спомошью группировки по колонке 'Genre' вычисляем среднее значения для каждого жанра  
del_dup_cinema.groupby('Genre').agg({
  "Audience score %": "std",
  "Profitability": "std",
  "Rotten Tomatoes %": "std",
  "Worldwide Gross": "std"  
}).reset_index()
# Out:
#        Genre  Audience score %  Profitability  Rotten Tomatoes %  \
# 0     Action               NaN            NaN                NaN
# 1  Animation         21.079216       2.030208          21.361960
# 2     Comedy         12.602380       3.799465          24.766459
# 3      Drama         12.794229      17.919544          25.533035
# 4    Fantasy               NaN            NaN                NaN
# 5    Romance         14.376568       3.562910          28.584378
#
#    Worldwide Gross
# 0              NaN
# 1       163.661964
# 2       129.717671
# 3       187.637972
# 4              NaN
# 5       183.186259
